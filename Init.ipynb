# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting pymc==5.21.1
#   Downloading pymc-5.21.1-py3-none-any.whl (517 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 517.9/517.9 kB 33.3 MB/s eta 0:00:00
# Collecting arviz==0.21.0
#   Downloading arviz-0.21.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.7/1.7 MB 90.8 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in /root/venv/lib/python3.10/site-packages (from pymc==5.21.1->-r ./requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: numpy>=1.25.0 in /root/venv/lib/python3.10/site-packages (from pymc==5.21.1->-r ./requirements.txt (line 2)) (1.25.2)
# Requirement already satisfied: scipy>=1.4.1 in /root/venv/lib/python3.10/site-packages (from pymc==5.21.1->-r ./requirements.txt (line 2)) (1.9.3)
# Collecting pytensor<2.29,>=2.28.2
#   Downloading pytensor-2.28.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.8/1.8 MB 89.2 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.2.1 in /root/venv/lib/python3.10/site-packages (from pymc==5.21.1->-r ./requirements.txt (line 2)) (5.5.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /root/venv/lib/python3.10/site-packages (from pymc==5.21.1->-r ./requirements.txt (line 2)) (4.13.2)
# Collecting rich>=13.7.1
#   Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 243.2/243.2 kB 29.8 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle in /root/venv/lib/python3.10/site-packages (from pymc==5.21.1->-r ./requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: pandas>=0.24.0 in /root/venv/lib/python3.10/site-packages (from pymc==5.21.1->-r ./requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: setuptools>=60.0.0 in /root/venv/lib/python3.10/site-packages (from arviz==0.21.0->-r ./requirements.txt (line 3)) (65.5.0)
# Collecting xarray-einstats>=0.3
#   Downloading xarray_einstats-0.8.0-py3-none-any.whl (32 kB)
# Collecting h5netcdf>=1.0.2
#   Downloading h5netcdf-1.6.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 49.6/49.6 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /root/venv/lib/python3.10/site-packages (from arviz==0.21.0->-r ./requirements.txt (line 3)) (25.0)
# Collecting xarray>=2022.6.0
#   Downloading xarray-2025.6.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.3/1.3 MB 74.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.5 in /root/venv/lib/python3.10/site-packages (from arviz==0.21.0->-r ./requirements.txt (line 3)) (3.6.3)
# Requirement already satisfied: h5py in /root/venv/lib/python3.10/site-packages (from h5netcdf>=1.0.2->arviz==0.21.0->-r ./requirements.txt (line 3)) (3.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.5->arviz==0.21.0->-r ./requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.5->arviz==0.21.0->-r ./requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.5->arviz==0.21.0->-r ./requirements.txt (line 3)) (11.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.5->arviz==0.21.0->-r ./requirements.txt (line 3)) (4.57.0)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.5->arviz==0.21.0->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.5->arviz==0.21.0->-r ./requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.5->arviz==0.21.0->-r ./requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas>=0.24.0->pymc==5.21.1->-r ./requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.10/site-packages (from pandas>=0.24.0->pymc==5.21.1->-r ./requirements.txt (line 2)) (2025.2)
# Collecting etuples
#   Downloading etuples-0.3.9.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting miniKanren
#   Downloading minikanren-1.0.4.tar.gz (21 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting cons
#   Downloading cons-0.4.6.tar.gz (26 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: filelock>=3.15 in /root/venv/lib/python3.10/site-packages (from pytensor<2.29,>=2.28.2->pymc==5.21.1->-r ./requirements.txt (line 2)) (3.18.0)
# Collecting logical-unification
#   Downloading logical-unification-0.4.6.tar.gz (31 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /root/venv/lib/python3.10/site-packages (from rich>=13.7.1->pymc==5.21.1->-r ./requirements.txt (line 2)) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 87.5/87.5 kB 16.8 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->arviz==0.21.0->-r ./requirements.txt (line 3)) (1.17.0)
# Collecting toolz
#   Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 56.4/56.4 kB 10.0 MB/s eta 0:00:00
# Collecting multipledispatch
#   Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Building wheels for collected packages: cons, logical-unification, etuples, miniKanren
#   Building wheel for cons (setup.py): started
#   Building wheel for cons (setup.py): finished with status 'done'
#   Created wheel for cons: filename=cons-0.4.6-py3-none-any.whl size=9092 sha256=84074ef1ccf9e6451d997df04f21d8ad97a4fd9a6933a12590596d934f871bfe
#   Stored in directory: /root/.cache/pip/wheels/a4/11/f5/8265470e17d280d8b5910e1b0f298521420a5086d696e96799
#   Building wheel for logical-unification (setup.py): started
#   Building wheel for logical-unification (setup.py): finished with status 'done'
#   Created wheel for logical-unification: filename=logical_unification-0.4.6-py3-none-any.whl size=13912 sha256=7ea84fa9d8ff1fc15893679eb13fa47df212c346b676504fcdf72aa0ff74e9ca
#   Stored in directory: /root/.cache/pip/wheels/ba/95/1f/29d557452d7f5102769deb2bdc49055be4505fb16c1b135a74
#   Building wheel for etuples (setup.py): started
#   Building wheel for etuples (setup.py): finished with status 'done'
#   Created wheel for etuples: filename=etuples-0.3.9-py3-none-any.whl size=12617 sha256=d19cdbb6cdc3ebaacb4fa9461f7155a0aabbca4023031db0fd0a44e30e66a863
#   Stored in directory: /root/.cache/pip/wheels/83/33/17/6acd5a85eb19ce3f6813a62546b63fd557757028e06e1a5203
#   Building wheel for miniKanren (pyproject.toml): started
#   Building wheel for miniKanren (pyproject.toml): finished with status 'done'
#   Created wheel for miniKanren: filename=minikanren-1.0.4-py3-none-any.whl size=24067 sha256=36c762946d4e41ce766acec9c5d7a5d2d8656b1b3942a3caffa3fe53ffa92b1e
#   Stored in directory: /root/.cache/pip/wheels/53/5a/02/91bcb1a8bd15b1e5653773d3dc35a19badb83f4165674c8880
# Successfully built cons logical-unification etuples miniKanren
# Installing collected packages: multipledispatch, toolz, mdurl, markdown-it-py, logical-unification, h5netcdf, xarray, rich, cons, xarray-einstats, etuples, miniKanren, arviz, pytensor, pymc
# Successfully installed arviz-0.21.0 cons-0.4.6 etuples-0.3.9 h5netcdf-1.6.1 logical-unification-0.4.6 markdown-it-py-3.0.0 mdurl-0.1.2 miniKanren-1.0.4 multipledispatch-1.0.0 pymc-5.21.1 pytensor-2.28.3 rich-14.0.0 toolz-1.0.0 xarray-2025.6.1 xarray-einstats-0.8.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
